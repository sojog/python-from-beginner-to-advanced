# %%
import math
print(math.sqrt(64))
# Out:
# 8.0

# %%
from math import sin
print(sin(100))
# Out:
# -0.5063656411097588

# %%
from math import cos as cosinus
print(cosinus(100))
# Out:
# 0.8623188722876839
